# %%
import pandas as pd
import re
import os

# %% [markdown]
# ## Electric Consumption/Expenditures by State

# %%
url = r"https://openei.org/doe-opendata/dataset/5e3b0afb-e8bb-4515-af2b-491d3e85123f/resource/"
seds = pd.read_csv(url + r"8a5a465a-2b92-49e3-9e94-862d10e3f272/download/completeseds19602009.csv")
seds.head()
# Out:
#      MSN StateCode  Year  Data
# 0  ABICB        AK  1960   0.0
# 1  ABICB        AK  1961   0.0
# 2  ABICB        AK  1962   0.0
# 3  ABICB        AK  1963   0.0
# 4  ABICB        AK  1964   0.0

# %%
codes = pd.read_csv(url + r"f9055073-cf01-4bdc-895d-c88e10738fb0/download/msncodesforsedsdata.csv")
codes.head()
# Out:
#      MSN                                        Description  \
# 0  ABICB  Aviation gasoline blending components consumed...
# 1  ABICP  Aviation gasoline blending components consumed...
# 2  ARICB  Asphalt and road oil consumed by the industria...
# 3  ARICD  Asphalt and road oil price in the industrial s...
# 4  ARICP  Asphalt and road oil consumed by the industria...
#
#                       Unit
# 0              Billion Btu
# 1         Thousand barrels
# 2              Billion Btu
# 3  Dollars per million Btu
# 4         Thousand barrels

# %%
type_codes = pd.read_csv(r"https://raw.githubusercontent.com/mkivenson/Visualization/master/Final%20Project/Datasets/State%20Energy%20Data%20System%201960-2009/energy_type_codes.csv")
type_codes
# Out:
#    Code                                   Name
# 0    AB  aviation gasoline blending components
# 1    AR                   asphalt and road oil
# 2    AV                      aviation gasoline
# 3    BM                                biomass
# 4    BQ                          normal butane
# ..  ...                                    ...
# 60   WD                                   wood
# 61   WS                          biomass waste
# 62   WW                 wood and biomass waste
# 63   WX                                  waxes
# 64   WY                                   wind
#
# [65 rows x 2 columns]

# %%
sector_codes = pd.read_csv(r"https://raw.githubusercontent.com/mkivenson/Visualization/master/Final%20Project/Datasets/State%20Energy%20Data%20System%201960-2009/sector_codes.csv")
sector_codes
# Out:
#   Code                                               Name
# 0   AC                  transportation sector consumption
# 1   CC                      commercial sector consumption
# 2   EI                  electric power sector consumption
# 3   HC  residential and commercial sectors combined co...
# 4   IC                      industrial sector consumption
# 5   RC                     residential sector consumption
# 6   TC                   total consumption of all sectors
# 7   TX           total consumption of all end-use sectors

# %%
states = pd.read_csv(url + r"ce23fee3-b75c-4e9a-9b8c-a1858ffe2684/download/postalcodesforsedsdata.csv")
states.head()
# Out:
#   Postal Code       State
# 0          AK      Alaska
# 1          AL     Alabama
# 2          AR    Arkansas
# 3          AZ     Arizona
# 4          CA  California

# %%
full_result = seds.merge(codes, on='MSN', how = 'left')
full_result = full_result.merge(type_codes, left_on=full_result['MSN'].str[0:2], right_on='Code', how = 'left')
full_result = full_result.merge(sector_codes, left_on=full_result['MSN'].str[2:4], right_on='Code', how = 'left')
full_result
# Out:
#         Code    MSN StateCode  Year         Data  \
# 0         IC  ABICB        AK  1960      0.00000
# 1         IC  ABICB        AK  1961      0.00000
# 2         IC  ABICB        AK  1962      0.00000
# 3         IC  ABICB        AK  1963      0.00000
# 4         IC  ABICB        AK  1964      0.00000
# ...      ...    ...       ...   ...          ...
# 1375816   TC  WYTCB        WY  2005   7171.92274
# 1375817   TC  WYTCB        WY  2006   7529.12606
# 1375818   TC  WYTCB        WY  2007   7461.24380
# 1375819   TC  WYTCB        WY  2008   9484.88887
# 1375820   TC  WYTCB        WY  2009  21727.75670
#
#                                                Description         Unit  \
# 0        Aviation gasoline blending components consumed...  Billion Btu
# 1        Aviation gasoline blending components consumed...  Billion Btu
# 2        Aviation gasoline blending components consumed...  Billion Btu
# 3        Aviation gasoline blending components consumed...  Billion Btu
# 4        Aviation gasoline blending components consumed...  Billion Btu
# ...                                                    ...          ...
# 1375816             Electricity produced from wind energy.  Billion Btu
# 1375817             Electricity produced from wind energy.  Billion Btu
# 1375818             Electricity produced from wind energy.  Billion Btu
# 1375819             Electricity produced from wind energy.  Billion Btu
# 1375820             Electricity produced from wind energy.  Billion Btu
#
#         Code_x                                 Name_x Code_y  \
# 0           AB  aviation gasoline blending components     IC
# 1           AB  aviation gasoline blending components     IC
# 2           AB  aviation gasoline blending components     IC
# 3           AB  aviation gasoline blending components     IC
# 4           AB  aviation gasoline blending components     IC
# ...        ...                                    ...    ...
# 1375816     WY                                   wind     TC
# 1375817     WY                                   wind     TC
# 1375818     WY                                   wind     TC
# 1375819     WY                                   wind     TC
# 1375820     WY                                   wind     TC
#
#                                    Name_y
# 0           industrial sector consumption
# 1           industrial sector consumption
# 2           industrial sector consumption
# 3           industrial sector consumption
# 4           industrial sector consumption
# ...                                   ...
# 1375816  total consumption of all sectors
# 1375817  total consumption of all sectors
# 1375818  total consumption of all sectors
# 1375819  total consumption of all sectors
# 1375820  total consumption of all sectors
#
# [1375821 rows x 11 columns]

# %%
full_result['MSN'].str[2:4]
# Out:
# 0          IC
# 1          IC
# 2          IC
# 3          IC
# 4          IC
#            ..
# 1375816    TC
# 1375817    TC
# 1375818    TC
# 1375819    TC
# 1375820    TC
# Name: MSN, Length: 1375821, dtype: object

# %%
full_result[(full_result.Description.str.contains('uclear', na = False) & full_result.MSN.str.contains('B', na = False))][['MSN','Description']]
# Out:
#           MSN                                        Description
# 865145  NUEGB  Electricity produced from nuclear power by the...
# 865146  NUEGB  Electricity produced from nuclear power by the...
# 865147  NUEGB  Electricity produced from nuclear power by the...
# 865148  NUEGB  Electricity produced from nuclear power by the...
# 865149  NUEGB  Electricity produced from nuclear power by the...
# ...       ...                                                ...
# 877100  NUETB           Electricity produced from nuclear power.
# 877101  NUETB           Electricity produced from nuclear power.
# 877102  NUETB           Electricity produced from nuclear power.
# 877103  NUETB           Electricity produced from nuclear power.
# 877104  NUETB           Electricity produced from nuclear power.
#
# [5200 rows x 2 columns]

# %%
energy_fields = [
     'Coal consumed by the commercial sector.',
     'Coal consumed by the industrial sector.',
     'Coal consumed by the residential sector.',
     'Coal total consumption.',
     'All petroleum products consumed by the commercial sector.',
     'All petroleum products consumed by the industrial sector.',
     'All petroleum products consumed by the residential sector.',
     'All petroleum products total consumption.',
     'Natural gas expenditures in the transportation sector.',
     'Natural gas consumed by (delivered to) the commercial sector (including supplemental gaseous fuels).',
     'Natural gas consumed by (delivered to) the industrial sector (including supplemental gaseous fuels).',
     'Natural gas consumed by (delivered to) the residential sector (including supplemental gaseous fuels).',
     'Natural gas total consumption (including supplemental gaseous fuels).',
     'Electricity consumed by (i.e., sold to) the commercial sector.',
     'Electricity consumed by (i.e., sold to) the industrial sector.',
     'Electricity consumed by (i.e., sold to) the residential sector.',
     'Electricity total consumption (i.e., sold).',
     'Total energy consumed by the commercial sector.',
     'Total energy consumed by the industrial sector.',
     'Total energy consumed by the residential sector.',
     'Total energy consumption.',
     'Total energy expenditures.']

# %%
result = full_result[full_result['Description'].isin(energy_fields)]
result.head()
# Out:
#          MSN StateCode  Year       Data  \
# 76486  CLCCB        AK  1960  495.85238
# 76487  CLCCB        AK  1961  495.78957
# 76488  CLCCB        AK  1962  593.30167
# 76489  CLCCB        AK  1963  392.99660
# 76490  CLCCB        AK  1964  306.14870
#
#                                    Description         Unit
# 76486  Coal consumed by the commercial sector.  Billion Btu
# 76487  Coal consumed by the commercial sector.  Billion Btu
# 76488  Coal consumed by the commercial sector.  Billion Btu
# 76489  Coal consumed by the commercial sector.  Billion Btu
# 76490  Coal consumed by the commercial sector.  Billion Btu

# %%
result['Energy Type'] = result['Description'].str.extract(r'(All petroleum products|Coal|Natural gas|Electricity|Total energy)')
result['Sector'] = result['Description'].str.extract(r'(commercial|industrial|residential|total)').fillna('total')
result.reset_index()
# Out:
# C:\Users\mkive\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mkive\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          index    MSN StateCode  Year        Data  \
# 0        76486  CLCCB        AK  1960   495.85238
# 1        76487  CLCCB        AK  1961   495.78957
# 2        76488  CLCCB        AK  1962   593.30167
# 3        76489  CLCCB        AK  1963   392.99660
# 4        76490  CLCCB        AK  1964   306.14870
# ...        ...    ...       ...   ...         ...
# 97755  1246180  TETCV        WY  2005  3674.47767
# 97756  1246181  TETCV        WY  2006  4320.10941
# 97757  1246182  TETCV        WY  2007  4533.06198
# 97758  1246183  TETCV        WY  2008  5581.09722
# 97759  1246184  TETCV        WY  2009  3894.93050
#
#                                    Description             Unit   Energy Type  \
# 0      Coal consumed by the commercial sector.      Billion Btu          Coal
# 1      Coal consumed by the commercial sector.      Billion Btu          Coal
# 2      Coal consumed by the commercial sector.      Billion Btu          Coal
# 3      Coal consumed by the commercial sector.      Billion Btu          Coal
# 4      Coal consumed by the commercial sector.      Billion Btu          Coal
# ...                                        ...              ...           ...
# 97755               Total energy expenditures.  Million dollars  Total energy
# 97756               Total energy expenditures.  Million dollars  Total energy
# 97757               Total energy expenditures.  Million dollars  Total energy
# 97758               Total energy expenditures.  Million dollars  Total energy
# 97759               Total energy expenditures.  Million dollars  Total energy
#
#            Sector
# 0      commercial
# 1      commercial
# 2      commercial
# 3      commercial
# 4      commercial
# ...           ...
# 97755       total
# 97756       total
# 97757       total
# 97758       total
# 97759       total
#
# [97760 rows x 9 columns]

# %%
os.chdir(r"C:\Users\mkive\Documents\GitHub\Visualization\Final Project\Datasets\State Energy Data System 1960-2009")
result.to_csv('preprocessed.csv', index = False)

# %%
full_result = (full_result[(full_result.MSN.str.endswith('CB')) | (full_result.MSN.str.endswith('EIB')) | (full_result.MSN == 'NUETB') | (full_result.MSN == 'ELNIB') | (full_result.MSN == 'NUEGB')])

# %%
full_result[full_result.Code == 'NU']
# Out:
#           MSN StateCode  Year  Data  \
# 865145  NUEGB        AK  1960   0.0
# 865146  NUEGB        AK  1961   0.0
# 865147  NUEGB        AK  1962   0.0
# 865148  NUEGB        AK  1963   0.0
# 865149  NUEGB        AK  1964   0.0
# ...       ...       ...   ...   ...
# 877100  NUETB        WY  2005   0.0
# 877101  NUETB        WY  2006   0.0
# 877102  NUETB        WY  2007   0.0
# 877103  NUETB        WY  2008   0.0
# 877104  NUETB        WY  2009   0.0
#
#                                               Description         Unit Code  \
# 865145  Electricity produced from nuclear power by the...  Billion Btu   NU
# 865146  Electricity produced from nuclear power by the...  Billion Btu   NU
# 865147  Electricity produced from nuclear power by the...  Billion Btu   NU
# 865148  Electricity produced from nuclear power by the...  Billion Btu   NU
# 865149  Electricity produced from nuclear power by the...  Billion Btu   NU
# ...                                                   ...          ...  ...
# 877100           Electricity produced from nuclear power.  Billion Btu   NU
# 877101           Electricity produced from nuclear power.  Billion Btu   NU
# 877102           Electricity produced from nuclear power.  Billion Btu   NU
# 877103           Electricity produced from nuclear power.  Billion Btu   NU
# 877104           Electricity produced from nuclear power.  Billion Btu   NU
#
#                           Name
# 865145  nuclear electric power
# 865146  nuclear electric power
# 865147  nuclear electric power
# 865148  nuclear electric power
# 865149  nuclear electric power
# ...                        ...
# 877100  nuclear electric power
# 877101  nuclear electric power
# 877102  nuclear electric power
# 877103  nuclear electric power
# 877104  nuclear electric power
#
# [5200 rows x 8 columns]

# %%
full_result.to_csv('full_data.csv', index = False)
